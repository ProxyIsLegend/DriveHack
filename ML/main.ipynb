# %%
import requests
from bs4 import BeautifulSoup
import pandas
from trackers import trackers
from datetime import date, timedelta

# %%
# techcrunch.com -> doesnt work properly with Requests, 
# should use Selenium instead ('load more' button)

# cbnc.com -> fine

# techstartups.com -> fine

# inc42.com -> doesnt work properly with Requests,
# should use Selenium instead ('load more' button)

# eu-startups.com -> fine

# techstars.com -> pagination doesnt work with Requests

# geekwire.com -> doesnt work without JS, should use Selenium instead

# startupnews.com.au -> website doesnt answer to requests

# pitchbook.com -> doesnt work properly with requests, 
# should use Selenium instead ('load more' button)

# cbinsights.com -> wtf?

# magazine.startus.cc -> doesnt work properly with Requests,
# should use Selenium instead ('load more' button)

# startupdaily.net -> blocks non-human requests

# %%
def iter_daterange(daterange: tuple[date]) -> list[date]:
    l, d = [], daterange[0]
    while d != daterange[1]:
        l.append(d)
        d += timedelta(1)
    return l

def s(url: str) -> BeautifulSoup:
    html = requests.get(url).content
    return BeautifulSoup(html, 'html.parser')

def month_convert(name_or_abb: str) -> int:
    pairs = {'jan': 1, 'feb': 2, 'mar': 3, 'apr': 4, 'may': 5, 'jun': 6,
             'jul': 7, 'aug': 8, 'sep': 9, 'oct': 10, 'nov': 11, 'dec': 12}
    return pairs[name_or_abb[:3].lower()]

def cringe_pag(page: int) -> int:
    return int(f'{page - 1}1')

# %%
class _m1Parser:
    # Parser for techstartups.com

    @classmethod
    def get_article_content(cls, soup: BeautifulSoup) -> str:
        post = soup.find('div', attrs={'class': 'post_wrapper'})
        text = ' '.join(tag.text for tag in post.find_all('p'))
        return text
    
    @classmethod
    def get_articles(cls, daterange: tuple[date]) -> list[tuple[str]]:
        items = []
        for d in trackers.ForTracker('techstartups.com', iter_daterange(daterange)):
            soup = s(f'https://techstartups.com/{d.year}/{d.month}/{d.day}')
            articles = soup.find('div', attrs={'class': 'sidebar_content'})
            if articles and 'error404' not in soup.body['class']:
                for link in [tag['href'] for tag in articles.find_all('a') if 'title' in tag.attrs]:
                    items.append((f'{d.year}.{d.month}.{d.day}', 'techstartups.com', link))
        return items


class _m2Parser:
    # Parser for cnbc.com

    @classmethod
    def get_article_content(cls, soup: BeautifulSoup) -> str:
        post = soup.find('div', attrs={'class': 'Article'})
        text = ' '.join(tag.text for tag in post.find_all('p'))
        return text
    
    @classmethod
    def get_articles(cls, daterange: tuple[date]) -> list[tuple[str]]:
        startedQ, finishedQ = False, False
        page, daterange = 1, iter_daterange(daterange)
        items = []
        while not finishedQ:
            articles = s(f'https://cnbc.com/startups/?page={page}') \
                .find_all('div', attrs={'class': 'Card-textContent'})
            for tag in articles:
                uri = tag.find('a', attrs={'class': 'Card-title'})['href']
                _ = uri.split('/')
                if _[3] == 'video': continue
                y, m, d = map(int, [_[3], _[4], _[5]])
                if date(y, m, d) in daterange: startedQ = True
                if date(y, m, d) not in daterange and startedQ: finishedQ = True 
                elif startedQ:
                    items.append((f'{y}.{m}.{d}', 'cnbc.com', uri))
            page += 1
        return items


class _m3Parser:
    # Parser for eu-startups.com

    @classmethod
    def get_article_content(cls, soup: BeautifulSoup) -> str:
        return soup.find('div', attrs={'class': 'tdi_83'}).get_text()
    
    @classmethod
    def get_articles(cls, daterange: tuple[date]) -> list[tuple[str]]:
        items = []
        for d in trackers.ForTracker('eu-startups.com', iter_daterange(daterange)):
            articles = s(f'https://eu-startups.com/{d.year}/{d.month}/{d.day}') \
                .find('div', attrs={'id': 'tdi_77'})
            if articles:
                for link in {tag['href'] for tag in articles.find_all('a') if 'title' in tag.attrs}:
                    items.append((f'{d.year}.{d.month}.{d.day}', 'eu-startups.com', link))
        return items
            

class Parser:
    
    methods = {
        'techstartups.com': _m1Parser,
        'cnbc.com': _m2Parser,
        'eu-startups.com': _m3Parser,
    }

    @classmethod
    def get_article_content(cls, url: str) -> str:
        domain = url.split('/')[2].replace('www.', '')
        html = requests.get(url).content
        soup = BeautifulSoup(html, 'html.parser')
        return cls.methods[domain].get_article_content(soup)
    
    @classmethod
    def get_articles(cls, domain: str, daterange: tuple[date] = None) -> list[tuple[str]]:
        if not daterange:
            daterange = (date.today() - timedelta(30), date.today())
        return cls.methods[domain].get_articles(daterange)

# %%
sources = (
    'techstartups.com',
    'cnbc.com',
    'eu-startups.com',
)

daterange = (
    date.today() - timedelta(90),
    date.today(),
)

urls = []
for source in sources:
    urls += Parser.get_articles(source, daterange)
# Out:
# (90/90) techstartups.com - 93.10s
# (90/90) eu-startups.com - 106.69s

# %%
print(len(urls))
urls
# Out:
# 680
# [('2022.5.29',
#   'techstartups.com',
#   'https://techstartups.com/2022/05/29/duckduckgo-caught-giving-microsoft-trackers-permission-track-users-third-party-sites-despite-strong-privacy-protection-claim/'),
#  ('2022.5.30',
#   'techstartups.com',
#   'https://techstartups.com/2022/05/30/12-traffic-originating-twitter-made-bots-study-israeli-cybersecurity-startup-cheq-found/'),
#  ('2022.5.30',
#   'techstartups.com',
#   'https://techstartups.com/2022/05/30/austrian-tech-startup-nxrt-raises-extra-2-3-million-expand-simulation-platform-automotive-railway-sectors/'),
#  ('2022.5.30',
#   'techstartups.com',
#   'https://techstartups.com/2022/05/30/candela-unveils-electric-flying-passenger-boat-zero-emissions-debuts-p-8-voyager-venice/'),
#  ('2022.5.31',
#   'techstartups.com',
#   'https://techstartups.com/2022/05/31/meta-apes-becomes-worlds-first-blockchain-game-go-live-bnb-application-sidechain-offers-best-web2-web3-gaming/'),
#  ('2022.5.31',
#   'techstartups.com',
#   'https://techstartups.com/2022/05/31/tech-billionaire-tim-draper-predicts-bitcoin-will-reach-250000-end-2022/'),
#  ('2022.5.31',
#   'techstartups.com',
#   'https://techstartups.com/2022/05/31/google-leads-300-million-funding-indias-sharechat-pushing-valuation-3-7-billion-5-billion-just-6-months/'),
#  ('2022.5.31',
#   'techstartups.com',
#   'https://techstartups.com/2022/05/31/apples-safari-browser-now-1-billion-users-internet-users-seek-alternatives-googles-browser/'),
#  ('2022.5.31',
#   'techstartups.com',
#   'https://techstartups.com/2022/05/31/bereal-new-gen-z-photo-sharing-app-prompts-users-take-one-unedited-photo-day-taking-social-media-storm/'),
#  ('2022.5.31',
#   'techstartups.com',
#   'https://techstartups.com/2022/05/31/finnish-cybersecurity-startup-hoxhunt-raises-40m-amid-raising-cyberattack-numbers/'),
#  ('2022.6.1',
#   'techstartups.com',
#   'https://techstartups.com/2022/06/01/sheryl-sandberg-stepping-facebooks-meta-coo/'),
#  ('2022.6.1',
#   'techstartups.com',
#   'https://techstartups.com/2022/06/01/refed-partners-closed-loop-partners-new-100m-circular-food-solutions-funding-platform-reduce-food-waste-led-google-others/'),
#  ('2022.6.1',
#   'techstartups.com',
#   'https://techstartups.com/2022/06/01/binance-launches-venture-capital-fund-500-million-initial-funding-invest-web3-blockchain-tech-startups/'),
#  ('2022.6.1',
#   'techstartups.com',
#   'https://techstartups.com/2022/06/01/elon-musk-says-leaked-email-tesla-employees-return-office-leave-company/'),
#  ('2022.6.1',
#   'techstartups.com',
#   'https://techstartups.com/2022/06/01/tezsure-launches-plenty-bridge-decentralized-bridge-let-users-transfer-tokens-ethereum-tezos-within-five-minutes/'),
#  ('2022.6.1',
#   'techstartups.com',
#   'https://techstartups.com/2022/06/01/us-top-cybersecurity-agency-says-electronic-voting-machines-used-least-16-states-software-vulnerabilities-leave-susceptible-hackers-ap-reports/'),
#  ('2022.6.1',
#   'techstartups.com',
#   'https://techstartups.com/2022/06/01/finnish-kitchen-tech-startup-huuva-raises-5-2m-general-catalyst-bring-delivery-food-outside-city-hot-spots/'),
#  ('2022.6.2',
#   'techstartups.com',
#   'https://techstartups.com/2022/06/02

#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/prague-10-exceptionally-promising-early-stage-startups-to-watch-in-2022/'),
#  ('2022.8.16',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/sweden-based-hygglo-acquires-uk-based-fat-llama-in-e41-million-deal-to-create-worlds-biggest-peer-to-peer-rental-platform/'),
#  ('2022.8.22',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/swiss-startup-peakdata-picks-up-e12-1-million-for-its-platform-connecting-pharma-companies-with-healthcare-professionals/'),
#  ('2022.8.22',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/super-important-pr-tactics-that-b2b-startups-need-to-know/'),
#  ('2022.8.22',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/15-of-the-best-startup-vc-newsletters-you-should-subscribe-to/'),
#  ('2022.8.22',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/vilnius-based-okredo-scores-e650k-for-its-open-data-platform/'),
#  ('2022.8.23',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/london-based-wombat-scores-over-e4-5-million-for-its-micro-investing-platform/'),
#  ('2022.8.23',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/sofia-based-nploy-swipes-e2-million-for-its-job-matching-platform/'),
#  ('2022.8.23',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/berlin-based-promiseq-scores-new-funding-to-fight-false-alarms-in-the-security-sector/'),
#  ('2022.8.23',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/stockholm-based-worldfavor-secures-e10-2-million-for-its-platform-empowering-business-sustainability/'),
#  ('2022.8.23',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/belgian-startup-setle-lands-e1-5-million-to-build-up-its-platform-supporting-sustainable-renovations/'),
#  ('2022.8.24',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/berlin-based-sagewealth-bags-e500k-for-its-next-gen-sustainable-investing-and-advisory-platform/'),
#  ('2022.8.24',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/eu-funding-opportunities-for-startups-join-our-2h-webinar-on-september-15/'),
#  ('2022.8.24',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/polish-firm-inovo-vc-announces-third-fund-with-e100-million-target-to-support-cee-tech-startups/'),
#  ('2022.8.24',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/the-weroad-journey-connecting-people-culture-and-stories-interview-with-erika-de-santi/'),
#  ('2022.8.24',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/german-startup-dryad-secures-e10-5-million-for-its-wildfire-detection-tech/'),
#  ('2022.8.24',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/lisbon-based-socialtalk-scores-e770k-to-harness-the-power-of-influencer-marketing/'),
#  ('2022.8.25',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/danish-startup-neurons-lands-over-e6-million-to-help-brands-understand-and-predict-customer-behaviours/'),
#  ('2022.8.25',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/thirdweb-raises-e24-million-for-its-platform-enabling-users-to-build-and-launch-web3-projects/'),
#  ('2022.8.25',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/10-greentech-startups-tackling-europes-waste-problem/'),
#  ('2022.8.25',
#   'eu-startups.com',
#   'https://www.eu-startups.com/2022/08/london-based-hometainment-exceeds-crowdfunding-target-to-shape-the-future-of-hospitality-experiences/')]

# %%
# NN part

# %%
import spacy

# %%
_ = [(*item, None) for item in urls]
df = pandas.DataFrame(data=_, columns=['date', 'source', 'link', 'content'])

# %%
for id, row in trackers.ForTracker('downloading content', list(df.iterrows())):
    if row.content is None:
        content = Parser.get_article_content(row.link)
        df.content[id] = content
# Out:
# (680/680) downloading content - 868.98s

# %%
# or import from file
pandas.read_csv('content.csv')
# Out:
#           date            source  \
# 0    2022.5.27  techstartups.com
# 1    2022.5.27  techstartups.com
# 2    2022.5.28  techstartups.com
# 3    2022.5.28  techstartups.com
# 4    2022.5.28  techstartups.com
# ..         ...               ...
# 791  2022.8.24   eu-startups.com
# 792  2022.8.24   eu-startups.com
# 793  2022.8.24   eu-startups.com
# 794  2022.8.24   eu-startups.com
# 795  2022.8.24   eu-startups.com
#
#                                                   link  \
# 0    https://techstartups.com/2022/05/27/layoffs-hi...
# 1    https://techstartups.com/2022/05/27/oracle-red...
# 2    https://techstartups.com/2022/08/25/australia-...
# 3    https://techstartups.com/2022/08/25/amazon-shu...
# 4    https://techstartups.com/2022/08/25/bitcoin-at...
# ..                                                 ...
# 791  https://www.eu-startups.com/2022/08/eu-funding...
# 792  https://www.eu-startups.com/2022/08/polish-fir...
# 793  https://www.eu-startups.com/2022/08/the-weroad...
# 794  https://www.eu-startups.com/2022/08/german-sta...
# 795  https://www.eu-startups.com/2022/08/lisbon-bas...
#
#                                                content
# 0    The current bear market has sent ripples aroun...
# 1    We covered Bybit back in March after the crypt...
# 2    The world’s food supply chain is broken and Sy...
# 3    In July, we wrote about Amazon after the retai...
# 4    Bitcoin Depot, the largest Bitcoin ATM operato...
# ..                                                 ...
# 791  The EU is running several large funding progra...
# 792  Polish venture capital firm Inovo VC has just ...
# 793  The travel industry has been on a rollercoaste...
# 794  Berlin-based Dryad has raised €10.5 million in...
# 795  Portuguese startup SocialTalk has raised €770k...
#
# [796 rows x 4 columns]

# %%
for id, row in list(df.iterrows()):
    df.content[id] = row.content.replace('\n', ' ').replace('\xa0', '') \
        .replace('\u200b', '').strip()

# %%
df
# Out:
#           date            source  \
# 0    2022.5.29  techstartups.com
# 1    2022.5.30  techstartups.com
# 2    2022.5.30  techstartups.com
# 3    2022.5.30  techstartups.com
# 4    2022.5.31  techstartups.com
# ..         ...               ...
# 675  2022.8.24   eu-startups.com
# 676  2022.8.25   eu-startups.com
# 677  2022.8.25   eu-startups.com
# 678  2022.8.25   eu-startups.com
# 679  2022.8.25   eu-startups.com
#
#                                                   link  \
# 0    https://techstartups.com/2022/05/29/duckduckgo...
# 1    https://techstartups.com/2022/05/30/12-traffic...
# 2    https://techstartups.com/2022/05/30/austrian-t...
# 3    https://techstartups.com/2022/05/30/candela-un...
# 4    https://techstartups.com/2022/05/31/meta-apes-...
# ..                                                 ...
# 675  https://www.eu-startups.com/2022/08/lisbon-bas...
# 676  https://www.eu-startups.com/2022/08/danish-sta...
# 677  https://www.eu-startups.com/2022/08/thirdweb-r...
# 678  https://www.eu-startups.com/2022/08/10-greente...
# 679  https://www.eu-startups.com/2022/08/london-bas...
#
#                                                content
# 0    For many of you who have been following us ove...
# 1    About two weeks ago, billionaire and Tesla CEO...
# 2    While many startups are still struggling to ra...
# 3    Candela is a Swedish tech startup and maker of...
# 4    Last week, we wrote about Ankr after theWeb3 i...
# ..                                                 ...
# 675  Portuguese startup SocialTalk has raised €770k...
# 676  Neurons has secured over €6 million in one of ...
# 677  Pioneering tech platform for building NFT and ...
# 678  Greentech is one of Europe’s biggest growth ar...
# 679  Home entertainment and hospitality platform, H...
#
# [680 rows x 4 columns]

# %%
df.to_csv('content.csv', index=False)

# %%
def extract_startups(article: str) -> list[str]:
    spacy_nlp = spacy.load('en_core_web_sm')
    text = article
    doc = spacy_nlp(text.strip())

    organizations = set()

    for entrance in doc.ents:
        entry = str(entrance.lemma_)
        text = text.replace(str(entrance), "")

        if entrance.label_ in ["ORG"]:
            organizations.add(entry)

    organizations = list(organizations)

    _ = set()
    for org in organizations:
        org = org.replace('’s', '')
        if org.lower() not in [i.lower() for i in _]:
            _.add(org)
    
    cleared_orgs = list(_)
    pairs = []

    for i, company in enumerate(cleared_orgs):
        url = f'https://search.yahoo.com/search;?p={"+".join(company.split())}'
        soup = s(url)
        try:
            res = soup.find('span', {'class': ['fz-14', 'lh-22']}).get_text()
            # print(company, res)
            numbers = int(res.split()[1].replace(",", ""))
            pairs.append((numbers, company))
        except AttributeError:
            pass
    
    # print(pairs)

    out = []
    for left, right in pairs:
        if left <= 30000: out.append(right)

    return out

# %%
keywords = (
    'transport', 'logistics', 'transportation', 'mobility', 'vehicle', 
    'car', 'bus', 'tram', 'underground', 'metro',
)

# %%
_df = pandas.DataFrame(columns=['date', 'source', 'link', 'entity'])

# %%
# or load from file
_df = pandas.read_csv('data.csv')

# %%
_df
# Out:
#          date            source  \
# 0   2022.5.30  techstartups.com
# 1   2022.5.30  techstartups.com
# 2   2022.5.31  techstartups.com
# 3    2022.6.2  techstartups.com
# 4    2022.6.2  techstartups.com
# 5    2022.6.2  techstartups.com
# 6    2022.6.2  techstartups.com
# 7    2022.6.2  techstartups.com
# 8    2022.6.2  techstartups.com
# 9    2022.6.6  techstartups.com
# 10   2022.6.6  techstartups.com
# 11   2022.6.6  techstartups.com
# 12   2022.6.6  techstartups.com
# 13   2022.6.7  techstartups.com
# 14   2022.6.7  techstartups.com
# 15   2022.6.7  techstartups.com
# 16   2022.6.7  techstartups.com
# 17   2022.6.7  techstartups.com
# 18   2022.6.7  techstartups.com
# 19   2022.6.7  techstartups.com
# 20   2022.6.7  techstartups.com
# 21   2022.6.7  techstartups.com
# 22   2022.6.8  techstartups.com
# 23   2022.6.8  techstartups.com
# 24   2022.6.9  techstartups.com
# 25   2022.6.9  techstartups.com
# 26   2022.6.9  techstartups.com
# 27  2022.6.10  techstartups.com
# 28  2022.6.13  techstartups.com
# 29  2022.6.14  techstartups.com
# 30  2022.6.15  techstartups.com
# 31  2022.6.15  techstartups.com
# 32  2022.6.15  techstartups.com
# 33  2022.6.15  techstartups.com
# 34  2022.6.17  techstartups.com
# 35  2022.6.20  techstartups.com
# 36  2022.6.21  techstartups.com
# 37  2022.6.21  techstartups.com
# 38  2022.6.22  techstartups.com
# 39  2022.6.22  techstartups.com
#
#                                                  link  \
# 0   https://techstartups.com/2022/05/30/austrian-t...
# 1   https://techstartups.com/2022/05/30/austrian-t...
# 2   https://techstartups.com/2022/05/31/finnish-cy...
# 3   https://techstartups.com/2022/06/02/gemini-cry...
# 4   https://techstartups.com/2022/06/02/gemini-cry...
# 5          https://techstartups.com/2022/06/02/65788/
# 6   https://techstartups.com/2022/06/02/marketacro...
# 7   https://techstartups.com/2022/06/02/marketacro...
# 8   https://techstartups.com/2022/06/02/marketacro...
# 9   https://techstartups.com/2022/06/06/british-te...
# 10  https://techstartups.com/2022/06/06/british-te...
# 11  https://techstartups.com/2022/06/06/british-te...
# 12  https://techstartups.com/2022/06/06/ceo-indone...
# 13  https://techstartups.com/2022/06/07/cake-defi-...
# 14  https://techstartups.com/2022/06/07/stockholm-...
# 15  https://techstartups.com/2022/06/07/thetanuts-...
# 16  https://techstartups.com/2022/06/07/thetanuts-...
# 17  https://techstartups.com/2022/06/07/thetanuts-...
# 18  https://techstartups.com/2022/06/07/thetanuts-...
# 19  https://techstartups.com/2022/06/07/israels-to...
# 20  https://techstartups.com/2022/06/07/israels-to...
# 21  https://techstartups.com/2022/06/07/israels-to...
# 22  https://techstartups.com/2022/06/08/baidus-ele...
# 23  https://techstartups.com/2022/06/08/baidus-ele...
# 24  https://techstartups.com/2022/06/09/athens-bas...
# 25  https://techstartups.com/2022/06/09/athens-bas...
# 26  https://techstartups.com/2022/06/09/spotify-ex...
# 27  https://techstartups.com/2022/06/10/goldman-sa...
# 28  https://techstartups.com/2022/06/13/michael-sa...
# 29  https://techstartups.com/2022/06/14/romanias-i...
# 30  https://techstartups.com/2022/06/15/proptech-s...
# 31  https://techstartups.com/2022/06/15/proptech-s...
# 32  https://techstartups.com/2022/06/15/proptech-s...
# 33  https://techstartups.com/2022/06/15/cybersecur...
# 34  https://techstartups.com/2022/06/17/israeli-te...
# 35  https://techstartups.com/2022/06/20/iranian-cy...
# 36  https://techstartups.com/2022/06/21/crypto-tec...
# 37  https://techstartups.com/2022/06/21/crypto-tec...
# 38  https://techstartups.com/2022/06/22/ex-sports-...
# 39  https://techstartups.com/2022/06/22/ex-sports-...
#
#                        entity
# 0                   eQventure
# 1      nxrt CEOLukas Stranger
# 2                     Hoxhunt
# 3                    ConnectU
# 4           HarvardConnection
# 5                     zkSNARK
# 6                   FactBlock
# 7                      UNOPND
# 8           Factblock & Korea
# 9                     cybsafe
# 10                    Hoxhunt
# 11                     Alashe
# 12                      Aluwi
# 13                 SportCares
# 14                 InsiderLog
# 15       thetanuts Stronghold
# 16                 thetanuts'
# 17          Thetanuts Finance
# 18                  Thetanuts
# 19              Aharon Dovrat
# 20                 PsiQuantum
# 21                 Amit Peled
# 22                   TTPlayer
# 23                 BaiduPedia
# 24                    Bryq AI
# 25                       Bryq
# 26                 CrowdAlbum
# 27    STORY3 Capital Partners
# 28                 @stockmart
# 29       Adrian Victor Vevera
# 30             Simpson,Altrio
# 31  Mantella Venture Partners
# 32              Altrio Origin
# 33     GreyNoise Intelligence
# 34     Indoor Robotics' Tando
# 35                   Radiflow
# 36     Beatclub and HyperMint
# 37                  HyperMint
# 38                  Urbanball
# 39        Urbanball Urbanball

# %%
skipQ = len(_df.index) != 0

for i, row in trackers.ForTracker('extracting startups', list(df.iterrows())):
# for i, row in list(df.iterrows())[:10]:
    if skipQ and row.link != _df.iloc[-1].link:
        continue
    else: skipQ = False
    if any([kw in row.content for kw in keywords]):
        sus = extract_startups(row.content)
        # print(sus)
        for su in sus:
            _ = pandas.DataFrame(
                {'date': [row.date], 'source': [row.source], 
                 'link': [row.link], 'entity': [su]}
            )
            _df = pandas.concat([_df, _], ignore_index=True, axis=0)
# Out:
# (680/680) extracting startups - 1992.05s

# %%
_df.drop_duplicates(ignore_index=True).to_csv('data.csv', index=False)
